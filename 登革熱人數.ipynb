# %%
'''
高雄市登革熱人數(不分男女)
'''

import requests, json
import urllib3
from datetime import datetime
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)


'''
台北市登革熱人數

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Taipei City':
            count = int(count) + int(1)  
TP = count
print("TP")
print(TP)

新北市登革熱人數

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'New Taipei City':
            count = int(count) + int(1)
         
NP = count
print("NP")
print(NP)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Taichung City':
            count = int(count) + int(1)
         
TX = count
print("TX")
print(TX)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Tainan City':
            count = int(count) + int(1)
         
TN = count
print("TN")
print(TN)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Kaohsiung City':
            count = int(count) + int(1)
         
KH = count
print("KH")
print(KH)
'''

sites = res.json()
count = int(0)
dd = {'Taipei City':0,'New Taipei City':0,'Taichung City':0,'Tainan City':0,'Kaohsiung City':0}

for site in sites:
    if site['County_living']=='Taipei City':
        dd['Taipei City'] += 1
    elif site['County_living']=='New Taipei City':
        dd['New Taipei City'] += 1 
    elif site['County_living']=='Taichung City':
        dd['Taichung City'] += 1 
    elif site['County_living']=='Tainan City':
        dd['Tainan City'] += 1 
    elif site['County_living']=='Kaohsiung City':
        dd['Kaohsiung City'] += 1 
        
print (dd)
# Out:
# {'Taipei City': 80, 'New Taipei City': 91, 'Taichung City': 56, 'Tainan City': 51, 'Kaohsiung City': 109}

# %%
'''
台北市登革熱人數(不分男女)
'''

import requests, json
import urllib3
from datetime import datetime
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Taipei City':
            count = int(count) + int(1)
            print( site['Date_Onset'] +'     '+str(count)+'     '+site['Sex'])

    with open("D:\\virous.json", 'wb') as f:
        f.write(res.content)
# Out:
# 2019/06/12     1     F
# 2019/06/16     2     F
# 2019/06/23     3     M
# 2019/06/25     4     M
# 2019/06/28     5     F
# 2019/06/30     6     M
# 2019/07/01     7     F
# 2019/07/05     8     M
# 2019/07/06     9     M
# 2019/07/08     10     F
# 2019/07/10     11     F
# 2019/07/11     12     M
# 2019/07/13     13     M
# 2019/07/16     14     M
# 2019/07/17     15     M
# 2019/07/20     16     M
# 2019/07/26     17     M
# 2019/07/27     18     M
# 2019/08/03     19     F
# 2019/08/05     20     M
# 2019/08/07     21     M
# 2019/08/08     22     M
# 2019/08/12     23     M
# 2019/08/15     24     M
# 2019/08/15     25     F
# 2019/08/17     26     F
# 2019/08/18     27     M
# 2019/08/19     28     M
# 2019/08/24     29     M
# 2019/08/25     30     F
# 2019/08/25     31     M
# 2019/08/27     32     M
# 2019/08/28     33     M
# 2019/08/31     34     M
# 2019/09/02     35     F
# 2019/09/08     36     M
# 2019/09/09     37     M
# 2019/09/14     38     F
# 2019/09/18     39     F
# 2019/09/18     40     M
# 2019/09/22     41     F
# 2019/09/26     42     M
# 2019/09/27     43     M
# 2019/09/27     44     F
# 2019/10/04     45     M
# 2019/10/05     46     F
# 2019/10/05     47     F
# 2019/10/06     48     M
# 2019/10/06     49     F
# 2019/10/06     50     M
# 2019/10/07     51     M
# 2019/10/18     52     F
# 2019/10/23     53     F
# 2019/10/23     54     F
# 2019/10/25     55     M
# 2019/10/26     56     F
# 2019/10/27     57     F
# 2019/10/27     58     F
# 2019/10/29     59     F
# 2019/11/08     60     M
# 2019/11/08     61     M
# 2019/11/11     62     M
# 2019/11/12     63     M
# 2019/11/18     64     M
# 2019/11/20     65     F
# 2019/11/21     66     M
# 2019/11/30     67     M
# 2019/12/02     68     F
# 2019/12/15     69     F
# 2019/12/19     70     M
# 2019/12/21     71     M
# 2019/12/29     72     M
# 2019/12/31     73     F
# 2020/01/01     74     F
# 2020/01/18     75     M
# 2020/01/31     76     M
# 2020/02/01     77     M
# 2020/02/07     78     M
# 2020/02/25     79     M
# 2020/03/10     80     F

# %%
'''
新北市登革熱人數(不分男女)
'''

import requests, json
import urllib3
from datetime import datetime
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'New Taipei City':
            count = int(count) + int(1)
            print( site['Date_Onset'] +'     '+str(count)+'     '+site['Sex'])

    with open("D:\\virous.json", 'wb') as f:
        f.write(res.content)
# Out:
# 2019/06/01     1     F
# 2019/06/03     2     M
# 2019/06/10     3     F
# 2019/06/23     4     F
# 2019/06/29     5     F
# 2019/06/30     6     M
# 2019/06/30     7     F
# 2019/07/04     8     M
# 2019/07/07     9     F
# 2019/07/10     10     F
# 2019/07/12     11     M
# 2019/07/16     12     F
# 2019/07/17     13     M
# 2019/07/17     14     M
# 2019/07/19     15     F
# 2019/07/19     16     M
# 2019/07/23     17     M
# 2019/07/23     18     F
# 2019/07/24     19     F
# 2019/07/25     20     M
# 2019/07/26     21     M
# 2019/07/26     22     M
# 2019/07/27     23     M
# 2019/08/03     24     F
# 2019/08/04     25     M
# 2019/08/05     26     M
# 2019/08/06     27     M
# 2019/08/06     28     M
# 2019/08/06     29     M
# 2019/08/08     30     M
# 2019/08/10     31     M
# 2019/08/13     32     F
# 2019/08/14     33     M
# 2019/08/15     34     F
# 2019/08/17     35     M
# 2019/08/17     36     M
# 2019/08/18     37     M
# 2019/08/20     38     F
# 2019/08/23     39     M
# 2019/08/23     40     F
# 2019/08/30     41     F
# 2019/09/11     42     M
# 2019/09/16     43     M
# 2019/09/19     44     M
# 2019/09/30     45     M
# 2019/10/01     46     M
# 2019/10/02     47     M
# 2019/10/08     48     M
# 2019/10/08     49     M
# 2019/10/11     50     M
# 2019/10/12     51     F
# 2019/10/14     52     M
# 2019/10/15     53     F
# 2019/10/16     54     M
# 2019/10/17     55     F
# 2019/10/19     56     M
# 2019/10/20     57     F
# 2019/10/21     58     F
# 2019/10/21     59     M
# 2019/10/26     60     F
# 2019/10/28     61     F
# 2019/10/31     62     F
# 2019/11/05     63     M
# 2019/11/05     64     F
# 2019/11/06     65     M
# 2019/11/15     66     M
# 2019/11/17     67     F
# 2019/11/18     68     M
# 2019/11/29     69     M
# 2019/12/06     70     F
# 2019/12/08     71     F
# 2019/12/10     72     F
# 2019/12/11     73     F
# 2019/12/11     74     F
# 2019/12/18     75     F
# 2019/12/30     76     F
# 2019/12/31     77     M
# 2020/01/05     78     M
# 2020/01/06     79     M
# 2020/01/16     80     M
# 2020/01/17     81     M
# 2020/01/22     82     M
# 2020/02/05     83     M
# 2020/02/05     84     M
# 2020/02/09     85     F
# 2020/02/23     86     M
# 2020/03/10     87     M
# 2020/03/15     88     M
# 2020/03/23     89     M
# 2020/04/19     90     M
# 2020/05/14     91     F

# %%
'''
台南市登革熱人數(不分男女)
'''

import requests, json
import urllib3
from datetime import datetime
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Tainan City':
            count = int(count) + int(1)
            print( site['Date_Onset'] +'     '+str(count)+'     '+site['Sex'])

    with open("D:\\virous.json", 'wb') as f:
        f.write(res.content)
# Out:
# 2019/06/13     1     M
# 2019/06/22     2     M
# 2019/06/29     3     F
# 2019/06/30     4     F
# 2019/06/30     5     F
# 2019/06/30     6     M
# 2019/07/02     7     F
# 2019/07/05     8     F
# 2019/07/06     9     F
# 2019/07/08     10     M
# 2019/07/08     11     M
# 2019/07/10     12     M
# 2019/07/12     13     M
# 2019/07/13     14     M
# 2019/07/14     15     M
# 2019/07/16     16     M
# 2019/07/16     17     M
# 2019/07/17     18     F
# 2019/07/18     19     M
# 2019/07/20     20     F
# 2019/07/21     21     F
# 2019/07/25     22     F
# 2019/07/28     23     M
# 2019/07/29     24     M
# 2019/08/06     25     M
# 2019/08/09     26     F
# 2019/08/09     27     F
# 2019/08/10     28     M
# 2019/08/11     29     F
# 2019/08/15     30     M
# 2019/08/20     31     M
# 2019/08/20     32     F
# 2019/08/25     33     M
# 2019/09/01     34     F
# 2019/09/05     35     F
# 2019/09/09     36     F
# 2019/09/12     37     M
# 2019/09/21     38     M
# 2019/09/23     39     M
# 2019/09/25     40     M
# 2019/09/26     41     F
# 2019/09/28     42     F
# 2019/10/06     43     M
# 2019/10/14     44     M
# 2019/11/08     45     F
# 2019/11/24     46     M
# 2020/01/05     47     F
# 2020/01/15     48     M
# 2020/01/24     49     M
# 2020/01/24     50     F
# 2020/03/04     51     M

# %%
'''
台中市登革熱人數(不分男女)
'''

import requests, json
import urllib3
from datetime import datetime
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)

sites = res.json()
count = int(0)
for site in sites:
    if site['County_living'] == 'Taichung City':
            count = int(count) + int(1)
            print( site['Date_Onset'] +'     '+str(count)+'     '+site['Sex'])

    with open("D:\\virous.json", 'wb') as f:
        f.write(res.content)
# Out:
# 2019/06/06     1     F
# 2019/06/14     2     F
# 2019/06/15     3     M
# 2019/06/16     4     M
# 2019/06/19     5     M
# 2019/06/22     6     F
# 2019/06/27     7     M
# 2019/07/01     8     M
# 2019/07/02     9     M
# 2019/07/05     10     F
# 2019/07/06     11     M
# 2019/07/10     12     F
# 2019/07/11     13     F
# 2019/07/13     14     M
# 2019/07/16     15     M
# 2019/07/19     16     M
# 2019/07/19     17     F
# 2019/07/19     18     F
# 2019/07/24     19     M
# 2019/07/24     20     M
# 2019/07/30     21     M
# 2019/07/31     22     F
# 2019/08/08     23     M
# 2019/08/18     24     F
# 2019/08/19     25     F
# 2019/08/27     26     M
# 2019/08/29     27     M
# 2019/09/03     28     F
# 2019/09/06     29     M
# 2019/09/07     30     F
# 2019/09/11     31     M
# 2019/09/12     32     M
# 2019/09/13     33     F
# 2019/09/26     34     M
# 2019/09/28     35     M
# 2019/10/03     36     M
# 2019/10/06     37     M
# 2019/10/09     38     M
# 2019/10/12     39     M
# 2019/10/24     40     F
# 2019/10/26     41     M
# 2019/10/30     42     M
# 2019/10/31     43     M
# 2019/11/01     44     M
# 2019/11/06     45     M
# 2019/11/10     46     M
# 2019/11/10     47     M
# 2019/11/27     48     M
# 2019/11/28     49     F
# 2019/12/17     50     M
# 2019/12/19     51     M
# 2020/01/26     52     F
# 2020/01/31     53     F
# 2020/02/26     54     M
# 2020/02/28     55     F
# 2020/03/17     56     M

# %%
'''
全國登革熱人數(男)
'''

import requests, json
import urllib3
from datetime import datetime
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)

sites = res.json()
count = int(0)
for site in sites:
    if site['Sex'] == 'M':
        count = int(count) + int(1)
        print( site['Date_Onset'] +'     '+str(count)+'     '+site['County_living'])

    with open("D:\\virous.json", 'wb') as f:
        f.write(res.content)
# Out:
# 2019/06/01     1     Kaohsiung City
# 2019/06/01     2     Kaohsiung City
# 2019/06/01     3     Kaohsiung City
# 2019/06/02     4     Kaohsiung City
# 2019/06/03     5     Kaohsiung City
# 2019/06/03     6     New Taipei City
# 2019/06/04     7     Changhua County
# 2019/06/04     8     Kaohsiung City
# 2019/06/06     9     Kaohsiung City
# 2019/06/06     10     Keelung City
# 2019/06/06     11     Kaohsiung City
# 2019/06/07     12     Taoyuan City
# 2019/06/09     13     Taoyuan City
# 2019/06/13     14     Tainan City
# 2019/06/15     15     Taichung City
# 2019/06/16     16     Kaohsiung City
# 2019/06/16     17     Taichung City
# 2019/06/17     18     Kaohsiung City
# 2019/12/31     267     New Taipei City
# 2020/01/04     268     Yunlin County
# 2020/01/05     269     Taoyuan City
# 2020/01/05     270     Changhua County
# 2020/01/05     271     New Taipei City
# 2020/01/06     272     New Taipei City
# 2020/01/09     273     Yilan County
# 2020/01/12     274     Kaohsiung City
# 2020/01/15     275     Changhua County
# 2020/01/15     276     Tainan City
# 2020/01/16     277     New Taipei City
# 2020/01/17     278     Taoyuan City
# 2020/01/17     279     New Taipei City
# 2020/01/18     280     Taipei City
# 2020/01/20     281     Kaohsiung City
# 2020/01/22     282     New Taipei City
# 2020/01/24     283     Tainan City
# 2020/01/31     284     Taipei City
# 2020/02/01     285     Taipei City
# 2020/02/05     286     New Taipei City
# 2020/02/05     287     New Taipei City
# 2020/02/07     288     Taipei City
# 2020/02/23     289     New Taipei City
# 2020/02/25     290     Taipei City
# 2020/02/26     291     Taichung City
# 2020/03/04     292     Tainan City
# 2020/03/10     293     New Taipei City
# 2020/03/13     294     Pingtung County
# 2020/03/15     295     New Taipei City
# 2020/03/17     296     Taichung City
# 2020/03/21     297     Kaohsiung City
# 2020/03/22     298     Changhua County
# 2020/03/23     299     New Taipei City
# 2020/03/23     300     Miaoli County
# 2020/04/19     301     New Taipei City

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# V1 版本开始支持链式调用
bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)
bar.render_notebook()

# 不习惯链式调用的开发者依旧可以单独调用方法
bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
bar.render_notebook()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 各 Chart 将在 1.9.0 版本开始强制使用 ChartItem 进行数据项配置
#   super().__init__(init_opts=init_opts)
# C:\Users\user\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 各 Chart 将在 1.9.0 版本开始强制使用 ChartItem 进行数据项配置
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8665be7fc9c3476ea751805cb30c6f39" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8665be7fc9c3476ea751805cb30c6f39 = echarts.init(
#                     document.getElementById('8665be7fc9c3476ea751805cb30c6f39'), 'white', {renderer: 'canvas'});
#                 var option_8665be7fc9c3476ea751805cb30c6f39 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8665be7fc9c3476ea751805cb30c6f39.setOption(option_8665be7fc9c3476ea751805cb30c6f39);
#         });
#     </script>

# %%
'''
高雄市登革熱人數(不分男女)
'''

import requests, json
import urllib3
from datetime import datetime
import pandas as pd
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

df = pd.DataFrame()

col1 = []
col2 = []
col3 = []


start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)

sites = res.json()
count = int(0)
for site in sites:
    try:
        with open("D:\\virous.json", 'wb') as f:
            col1.append(site['Date_Onset'])
            col2.append(str(count))
            col3.append(site['Sex'])
            
            
df['時'] = pd.Series(col1)
df['數'] = pd.Series(col2)
df['性別'] = pd.Series(col3)
# Out:
#   File "<ipython-input-20-348987b984a2>", line 32
#     df['時'] = pd.Series(col1)
#                              ^
# IndentationError: unexpected unindent
